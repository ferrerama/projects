# %%
year <- c(2010,2011,2012,2013)
Nauffar <-c(13,10,14,15)

plot(x=year, y= Nauffar, main = Nauffar, xlab='', ylab='', col='cornflowerblue', pch=16, panel.first = grid())
# Out:
# Plot with title "13"
# Plot with title "10"
# Plot with title "14"
# Plot with title "15"
