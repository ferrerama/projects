# %%
import pandas as pd
import xlwings as xw

# %%
ruta = r"C:\Users\mferrera\Desktop\ws\2m Sales Records.csv"
datos1=pd.read_csv(ruta)
datos1
# Out:
#                                     Region     Country        Item Type  \
# 0                    Australia and Oceania   Australia             Meat
# 1                                     Asia  Tajikistan    Personal Care
# 2                       Sub-Saharan Africa  Mozambique        Cosmetics
# 3        Central America and the Caribbean      Panama    Personal Care
# 4                            North America      Canada           Fruits
# ...                                    ...         ...              ...
# 1999995                 Sub-Saharan Africa    Djibouti        Cosmetics
# 1999996                             Europe     Armenia           Snacks
# 1999997  Central America and the Caribbean    Dominica       Vegetables
# 1999998                 Sub-Saharan Africa       Kenya  Office Supplies
# 1999999                 Sub-Saharan Africa    Tanzania           Snacks
#
#         Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
datos3=xw.load()

# %%
datos3
# Out:
#       Ventas
# Pais
# A      334.0
# B      433.0
# A      111.0
# C       33.0
